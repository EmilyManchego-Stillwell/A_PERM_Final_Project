# %%
import pandas as pd

# %%
fires = pd.read_csv("WFIGS_-_Wildland_Fire_Locations_Full_History.csv")

fires.head()
# Out:
#             X          Y  OBJECTID ABCDMisc ADSPermissionState  \
# 0 -106.705910  39.742896       400      NaN            DEFAULT
# 1 -107.774211  37.806806       484      NaN          CERTIFIED
# 2 -106.881410  39.138766      1750     EKU9            DEFAULT
# 3 -108.418611  39.762136      3400      NaN          CERTIFIED
# 4 -105.057510  40.882507      4685      NaN            DEFAULT
#
#    CalculatedAcres     ContainmentDateTime         ControlDateTime  \
# 0              NaN  2018/06/17 20:00:00+00  2018/06/27 21:27:00+00
# 1         597.8200  2020/10/27 14:00:00+00  2020/11/19 21:00:00+00
# 2              NaN  2016/11/28 19:44:59+00  2016/11/28 20:00:00+00
# 3        3128.2127  2020/07/23 13:30:00+00  2020/09/10 14:00:00+00
# 4              NaN                     NaN                     NaN
#
#    DailyAcres  DiscoveryAcres  ... IsDispatchComplete  \
# 0       455.0            20.0  ...                  0
# 1       597.8             1.0  ...                  0
# 2         2.0             0.1  ...                  0
# 3      3226.0             1.0  ...                  0
# 4      2200.0           100.0  ...                  0
#
#    OrganizationalAssessment  StrategicDecisionPublishDate  \
# 0                       NaN                           NaN
# 1           Type 3 Incident        2020/10/22 23:26:51+00
# 2                       NaN                           NaN
# 3           Type 2 Incident        2020/07/16 14:48:53+00
# 4                       NaN                           NaN
#
#      CreatedOnDateTime_dt   ModifiedOnDateTime_dt Source  \
# 0  2018/06/09 22:02:35+00  2018/09/28 18:22:22+00  IRWIN
# 1  2020/10/19 20:22:28+00  2021/01/13 20:23:23+00  IRWIN
# 2  2016/09/18 18:09:26+00  2018/08/24 21:59:00+00  IRWIN
# 3  2020/07/13 18:51:22+00  2020/10/13 17:05:51+00  IRWIN
# 4  2017/03/04 23:21:27+00  2017/03/22 15:16:32+00  IRWIN
#
#                                  GlobalID IsCpxChild CpxName CpxID
# 0  {0175FA2C-A729-434F-9F79-C95775A5992B}        NaN     NaN   NaN
# 1  {C8771DB9-FF8E-4BFC-9695-F3BBEB775FAB}        NaN     NaN   NaN
# 2  {7532502C-4452-4B0E-B837-98D92B27AA15}        NaN     NaN   NaN
# 3  {10D79D0D-C571-4FD4-AE3D-E7C604AB6D14}        NaN     NaN   NaN
# 4  {EBF446AE-0303-435A-9638-6A7804E26E81}        NaN     NaN   NaN
#
# [5 rows x 96 columns]

# %%
fires["YEAR"]=pd.DatetimeIndex(fires["FireDiscoveryDateTime"]).year
small_fires = fires[["YEAR", "POOCounty", "X"]]

# %%
# group by year, then county and count the X column so that we get a count of the number of wildfires in each county in each year
final = small_fires.groupby(by=["YEAR", "POOCounty"]).count()

# %%
# save the df as a dictionary 
county_year_dict = final.to_dict()['X']

# %%
# test to see if try/except will work by calling a (year, county) key from the dictionary
counties = ['Archuleta', 'Baca']
years = [2015, 2016, 2017, 2018]

for year in years:
    for county in counties:
        try:
            print(county_year_dict[(year, county)])
        except KeyError:
            print(0)
# Out:
# 4
# 0
# 2
# 0
# 3
# 0
# 2
# 1
